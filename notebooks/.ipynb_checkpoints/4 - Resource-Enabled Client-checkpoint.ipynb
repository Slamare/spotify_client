# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests) (1.25.9)

# %%
import requests
import datetime
from urllib.parse import urlencode

# %%
import base64

# %%
client_id =  'fdef75a5c7c84ac897d975203234b683'
client_secret = '30eefdba8cf6401daac9bf8a97188e91'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        
        
    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None: 
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return{
            "Authorization": f"Basic {client_creds_b64}"}
    
    def get_token_data(self):
        return {
            'grant_type': 'client_credentials'
        }
        
    def perform_auth(self):
        token_url = self.token_url
        token_data = self. get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            return Eception("Could not authenticate client.")
            #return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds=expires_in) #datetime object relative to now
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now: 
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
 
    def get_resource(self, lookup_id, resource_type="albums", version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
                return {}
        return r.json()
    
    def get_album(self,_id ):
        return self.get_resource(_id, resource_type="albums")
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type="artist")
    
    def search(self, query, search_type='artist'): #type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query , "type": search_type.lower()})
        lookup_url = f"{endpoint}?{data}"
        print(lookup_url)
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):
            return{}
        return r.json()

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search("A lannister alwyas pays his debts", search_type="track")
# Out:
# https://api.spotify.com/v1/search?q=A+lannister+alwyas+pays+his+debts&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=A+lannister+alwyas+pays+his+debts&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/41zMFsCjcGenYKVJYUXU2n'},
#      'href': 'https://api.spotify.com/v1/albums/41zMFsCjcGenYKVJYUXU2n',
#      'id': '41zMFsCjcGenYKVJYUXU2n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362be9b16adb2e32aed9bda26',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262be9b16adb2e32aed9bda26',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162be9b16adb2e32aed9bda26',
#        'width': 64}],
#      'name': 'Game Of Thrones: Season 3 (Music from the HBO Series)',
#      'release_date': '2013-06-04',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:41zMFsCjcGenYKVJYUXU2n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 170560,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1300355'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1vPEPhmGDnp8RR6GCBozaa'},
#     'href': 'https://api.spotify.com/v1/tracks/1vPEPhmGDnp8RR6GCBozaa',
#     'id': '1vPEPhmGDnp8RR6GCBozaa',
#     'is_local': False,
#     'name': 'A Lannister Always Pays His Debts',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/43d967066f07ecdf7daded0bdc521adc73a0f07a?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1vPEPhmGDnp8RR6GCBozaa'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6i9KFEJuHq78nMsQxeB1vR'},
#        'href': 'https://api.spotify.com/v1/artists/6i9KFEJuHq78nMsQxeB1vR',
#        'id': '6i9KFEJuHq78nMsQxeB1vR',
#        'name': 'NDR Radiophilharmonie',
#        'type': 'artist',
#        'uri': 'spotify:artist:6i9KFEJuHq78nMsQxeB1vR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7BuKIq2YqVZhxSdquEnwko'},
#        'href': 'https://api.spotify.com/v1/artists/7BuKIq2YqVZhxSdquEnwko',
#        'id': '7BuKIq2YqVZhxSdquEnwko',
#        'name': 'Ben Palmer',
#        'type': 'artist',
#        'uri': 'spotify:artist:7BuKIq2YqVZhxSdquEnwko'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Sln4IGWh4meWU5fg9tJ7G'},
#      'href': 'https://api.spotify.com/v1/albums/2Sln4IGWh4meWU5fg9tJ7G',
#      'id': '2Sln4IGWh4meWU5fg9tJ7G',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27300b1d540b9170873eecb69da',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0200b1d540b9170873eecb69da',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485100b1d540b9170873eecb69da',
#        'width': 64}],
#      'name': 'A Lannister Always Pays His Debts',
#      'release_date': '2020-01-31',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2Sln4IGWh4meWU5fg9tJ7G'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6i9KFEJuHq78nMsQxeB1vR'},
#       'href': 'https://api.spotify.com/v1/artists/6i9KFEJuHq78nMsQxeB1vR',
#       'id': '6i9KFEJuHq78nMsQxeB1vR',
#       'name': 'NDR Radiophilharmonie',
#       'type': 'artist',
#       'uri': 'spotify:artist:6i9KFEJuHq78nMsQxeB1vR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7BuKIq2YqVZhxSdquEnwko'},
#       'href': 'https://api.spotify.com/v1/artists/7BuKIq2YqVZhxSdquEnwko',
#       'id': '7BuKIq2YqVZhxSdquEnwko',
#       'name': 'Ben Palmer',
#       'type': 'artist',
#       'uri': 'spotify:artist:7BuKIq2YqVZhxSdquEnwko'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 173667,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE861903694'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7bepfooXfeEsSK75XGo3W1'},
#     'href': 'https://api.spotify.com/v1/tracks/7bepfooXfeEsSK75XGo3W1',
#     'id': '7bepfooXfeEsSK75XGo3W1',
#     'is_local': False,
#     'name': 'A Lannister Always Pays His Debts',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a93c54ddcbb0cdca02412cbd641cd6930d6a75e6?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7bepfooXfeEsSK75XGo3W1'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 2}}

# %%
spotify.get_artist("6fOMl44jA4Sp5b9PpYCkzz")
# Out:
# {}

# %%
spotify.get_album("41zMFsCjcGenYKVJYUXU2n")
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#    'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#    'id': '1hCkSJcXREhrodeIHQdav8',
#    'name': 'Ramin Djawadi',
#    'type': 'artist',
#    'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#  'available_markets': ['AD',
#   'AE',
#   'AL',
#   'AR',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'BY',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'KZ',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MK',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'SA',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'UA',
#   'US',
#   'UY',
#   'VN',
#   'XK',
#   'ZA'],
#  'copyrights': [{'text': '2013 Game Of Thrones, Artwork and Photographs © 2013 Home Box Office, Inc. All Rights Reserved. HBO and related trademarks are the property of Home Box Office, Inc.',
#    'type': 'C'},
#   {'text': '2013 This compilation WaterTower Music as licensee for Warner Bros. Entertainment Inc.',
#    'type': 'P'}],
#  'external_ids': {'upc': '794043170065'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/41zMFsCjcGenYKVJYUXU2n'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/41zMFsCjcGenYKVJYUXU2n',
#  'id': '41zMFsCjcGenYKVJYUXU2n',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27362be9b16adb2e32aed9bda26',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0262be9b16adb2e32aed9bda26',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485162be9b16adb2e32aed9bda26',
#    'width': 64}],
#  'label': 'WaterTower Music',
#  'name': 'Game Of Thrones: Season 3 (Music from the HBO Series)',
#  'popularity': 60,
#  'release_date': '2013-06-04',
#  'release_date_precision': 'day',
#  'total_tracks': 19,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/41zMFsCjcGenYKVJYUXU2n/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 104266,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0M9QjRGZhvqJATvgQS4Hob'},
#     'href': 'https://api.spotify.com/v1/tracks/0M9QjRGZhvqJATvgQS4Hob',
#     'id': '0M9QjRGZhvqJATvgQS4Hob',
#     'is_local': False,
#     'name': 'Main Title (From Game of Thrones: Season 3)',
#     'preview_url': 'https://p.scdn.co/mp3-preview/d2293343b9986a0ccae4bd180e39e1ce62c81a94?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0M9QjRGZhvqJATvgQS4Hob'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 170560,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1vPEPhmGDnp8RR6GCBozaa'},
#     'href': 'https://api.spotify.com/v1/tracks/1vPEPhmGDnp8RR6GCBozaa',
#     'id': '1vPEPhmGDnp8RR6GCBozaa',
#     'is_local': False,
#     'name': 'A Lannister Always Pays His Debts',
#     'preview_url': 'https://p.scdn.co/mp3-preview/43d967066f07ecdf7daded0bdc521adc73a0f07a?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1vPEPhmGDnp8RR6GCBozaa'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 173386,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1eW5pYWfahrmseEKvCyoYR'},
#     'href': 'https://api.spotify.com/v1/tracks/1eW5pYWfahrmseEKvCyoYR',
#     'id': '1eW5pYWfahrmseEKvCyoYR',
#     'is_local': False,
#     'name': 'Dracarys',
#     'preview_url': 'https://p.scdn.co/mp3-preview/c9ed0fdb98772a1eddc210e20ff044307d74b646?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1eW5pYWfahrmseEKvCyoYR'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 195546,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ra1Rf7DgDkfKNoZOh3MRb'},
#     'href': 'https://api.spotify.com/v1/tracks/3ra1Rf7DgDkfKNoZOh3MRb',
#     'id': '3ra1Rf7DgDkfKNoZOh3MRb',
#     'is_local': False,
#     'name': 'I Paid the Iron Price',
#     'preview_url': 'https://p.scdn.co/mp3-preview/040e06b8a7180b182ec32e7138354b6179b9ff26?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3ra1Rf7DgDkfKNoZOh3MRb'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 178333,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6iEvRqryWDEFleImTSLqR4'},
#     'href': 'https://api.spotify.com/v1/tracks/6iEvRqryWDEFleImTSLqR4',
#     'id': '6iEvRqryWDEFleImTSLqR4',
#     'is_local': False,
#     'name': 'Chaos Is a Ladder',
#     'preview_url': 'https://p.scdn.co/mp3-preview/13f4392bf77ce2b1b0e7d2d2b3b171df73002654?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6iEvRqryWDEFleImTSLqR4'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 167906,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2YZy9wVrWyWIGJK7LsJbgZ'},
#     'href': 'https://api.spotify.com/v1/tracks/2YZy9wVrWyWIGJK7LsJbgZ',
#     'id': '2YZy9wVrWyWIGJK7LsJbgZ',
#     'is_local': False,
#     'name': 'Dark Wings, Dark Words',
#     'preview_url': 'https://p.scdn.co/mp3-preview/ebbfd18f99175822e56f26a843e2bfcbf9b8e920?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2YZy9wVrWyWIGJK7LsJbgZ'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 199893,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0KKPRgsM7LkJqhYgofhgkO'},
#     'href': 'https://api.spotify.com/v1/tracks/0KKPRgsM7LkJqhYgofhgkO',
#     'id': '0KKPRgsM7LkJqhYgofhgkO',
#     'is_local': False,
#     'name': 'You Know Nothing',
#     'preview_url': 'https://p.scdn.co/mp3-preview/7c955f2f6017bf5af5339cc8d2680584dad8cd4c?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:0KKPRgsM7LkJqhYgofhgkO'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 199733,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3JYunrNOpvAtBEj9akySsG'},
#     'href': 'https://api.spotify.com/v1/tracks/3JYunrNOpvAtBEj9akySsG',
#     'id': '3JYunrNOpvAtBEj9akySsG',
#     'is_local': False,
#     'name': 'Wall Of Ice',
#     'preview_url': 'https://p.scdn.co/mp3-preview/a3380dd6c1ad6240f026e13adf86091c61951f0f?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:3JYunrNOpvAtBEj9akySsG'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 131026,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4kkJe2xKp25GU3NA3rRCSl'},
#     'href': 'https://api.spotify.com/v1/tracks/4kkJe2xKp25GU3NA3rRCSl',
#     'id': '4kkJe2xKp25GU3NA3rRCSl',
#     'is_local': False,
#     'name': 'Kingslayer',
#     'preview_url': 'https://p.scdn.co/mp3-preview/f7c83e5638f07af17e19870db33a49d06b0e4567?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:4kkJe2xKp25GU3NA3rRCSl'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 83013,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7zHgw57kui6pUeG4ITslMX'},
#     'href': 'https://api.spotify.com/v1/tracks/7zHgw57kui6pUeG4ITslMX',
#     'id': '7zHgw57kui6pUeG4ITslMX',
#     'is_local': False,
#     'name': 'I Have to Go North',
#     'preview_url': 'https://p.scdn.co/mp3-preview/b10e17945e879b8069f5e294298dfb7abaf2e82a?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7zHgw57kui6pUeG4ITslMX'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 200680,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/00deiAYxr1qQx4km9ftnPK'},
#     'href': 'https://api.spotify.com/v1/tracks/00deiAYxr1qQx4km9ftnPK',
#     'id': '00deiAYxr1qQx4km9ftnPK',
#     'is_local': False,
#     'name': 'White Walkers',
#     'preview_url': 'https://p.scdn.co/mp3-preview/782989f3995ed730ab31714c048baf12b8d8f6c4?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:00deiAYxr1qQx4km9ftnPK'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7aRFEB5l1p8480dl8lCTVD'},
#       'href': 'https://api.spotify.com/v1/artists/7aRFEB5l1p8480dl8lCTVD',
#       'id': '7aRFEB5l1p8480dl8lCTVD',
#       'name': 'Kerry Ingram',
#       'type': 'artist',
#       'uri': 'spotify:artist:7aRFEB5l1p8480dl8lCTVD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 77946,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/43sz4PFPSPqCzJVRnsgPXT'},
#     'href': 'https://api.spotify.com/v1/tracks/43sz4PFPSPqCzJVRnsgPXT',
#     'id': '43sz4PFPSPqCzJVRnsgPXT',
#     'is_local': False,
#     'name': "It's Always Summer Under the Sea (Shireen's Song)",
#     'preview_url': 'https://p.scdn.co/mp3-preview/6361d4c3879178cecf2405811ffd19d24a715c5f?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:43sz4PFPSPqCzJVRnsgPXT'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 161800,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1HL3s0OdfwxUuwgGAT0zFp'},
#     'href': 'https://api.spotify.com/v1/tracks/1HL3s0OdfwxUuwgGAT0zFp',
#     'id': '1HL3s0OdfwxUuwgGAT0zFp',
#     'is_local': False,
#     'name': 'Reek',
#     'preview_url': 'https://p.scdn.co/mp3-preview/04a0d497c083127853a179e7e8bfc7962c057d49?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:1HL3s0OdfwxUuwgGAT0zFp'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qkZBMz5JgmRN9u5wwhRC6'},
#       'href': 'https://api.spotify.com/v1/artists/3qkZBMz5JgmRN9u5wwhRC6',
#       'id': '3qkZBMz5JgmRN9u5wwhRC6',
#       'name': 'The Hold Steady',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qkZBMz5JgmRN9u5wwhRC6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 176013,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6rR6ixVWgJHWIGLWYduP7Y'},
#     'href': 'https://api.spotify.com/v1/tracks/6rR6ixVWgJHWIGLWYduP7Y',
#     'id': '6rR6ixVWgJHWIGLWYduP7Y',
#     'is_local': False,
#     'name': 'The Bear And the Maiden Fair',
#     'preview_url': 'https://p.scdn.co/mp3-preview/e991f935246f61764eb8f4460cbdbe4b02b2e7c7?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:6rR6ixVWgJHWIGLWYduP7Y'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 176226,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3x2BUNToiv9ARdvP0z04o4'},
#     'href': 'https://api.spotify.com/v1/tracks/3x2BUNToiv9ARdvP0z04o4',
#     'id': '3x2BUNToiv9ARdvP0z04o4',
#     'is_local': False,
#     'name': 'The Night Is Dark',
#     'preview_url': 'https://p.scdn.co/mp3-preview/1de44c53b89c10f8dca69e2696194698ceb26507?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:3x2BUNToiv9ARdvP0z04o4'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 344026,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0qKL49f02I5BCc4IwljtUt'},
#     'href': 'https://api.spotify.com/v1/tracks/0qKL49f02I5BCc4IwljtUt',
#     'id': '0qKL49f02I5BCc4IwljtUt',
#     'is_local': False,
#     'name': 'The Lannisters Send Their Regards',
#     'preview_url': 'https://p.scdn.co/mp3-preview/af076eeffb4e05ec2d7cdf756efb6884f1dc0fbb?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:0qKL49f02I5BCc4IwljtUt'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 134186,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6hL134phTqx5bNFcVtbSyq'},
#     'href': 'https://api.spotify.com/v1/tracks/6hL134phTqx5bNFcVtbSyq',
#     'id': '6hL134phTqx5bNFcVtbSyq',
#     'is_local': False,
#     'name': 'Heir to Winterfell',
#     'preview_url': 'https://p.scdn.co/mp3-preview/0643caa9ecba612ef858d81ed7a9a4ccdf6d4a67?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:6hL134phTqx5bNFcVtbSyq'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 234933,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4wxaEgPlUbEUwiAnThBUkw'},
#     'href': 'https://api.spotify.com/v1/tracks/4wxaEgPlUbEUwiAnThBUkw',
#     'id': '4wxaEgPlUbEUwiAnThBUkw',
#     'is_local': False,
#     'name': 'Mhysa',
#     'preview_url': 'https://p.scdn.co/mp3-preview/c491f2f50a4192b5b90338bcf7e55c0d6d3cada1?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:4wxaEgPlUbEUwiAnThBUkw'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 91093,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3CNGmZVbvs4UVY2fWHXBvD'},
#     'href': 'https://api.spotify.com/v1/tracks/3CNGmZVbvs4UVY2fWHXBvD',
#     'id': '3CNGmZVbvs4UVY2fWHXBvD',
#     'is_local': False,
#     'name': 'For the Realm',
#     'preview_url': 'https://p.scdn.co/mp3-preview/92dd746c229454996f2f7bcf213949bef2440a01?cid=fdef75a5c7c84ac897d975203234b683',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:3CNGmZVbvs4UVY2fWHXBvD'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 19},
#  'type': 'album',
#  'uri': 'spotify:album:41zMFsCjcGenYKVJYUXU2n'}
